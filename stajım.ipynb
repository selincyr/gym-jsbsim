# %% [markdown]
# <a href="https://colab.research.google.com/github/selincyr/gym-jsbsim/blob/master/staj%C4%B1m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd content
# Out:
# [Errno 2] No such file or directory: 'content'
# /content
